# %% [markdown]
# # 🍎 Prompt Engineering Techniques with AIProjectClient 🍏
#
# En este cuaderno, demostraremos algunas técnisa de `Prompt Engineering` utilizando el SDK **Azure AI Foundry**. Combinaremos los paquetes **`azure-ai-projects`** y **`azure-ai-inference`** para:
#
# 1. **Inicializar** un `AIProjectClient`.
# 2. **Obtener** un cliente de Chat Completions para realizar llamadas directas al LLM.
# 3. **Utilizar** diferentes **plantillas de prompt** para añadir el contexto del sistema.
# 4. **Enviar** mensajes de usuario con una temática de salud y fitness.

# %% [markdown]
# ## 1. Initial Setup
#
# Cargar variables de entorno, crear un `AIProjectClient`, y obtener un `ChatCompletionsClient`. También definiremos un prompt template para mostrar cómo se podría estructurar un system message.

# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from azure.identity import DefaultAzureCredential
from azure.ai.inference.prompts import PromptTemplate
from azure.ai.projects import AIProjectClient
from azure.ai.inference.models import UserMessage, SystemMessage  # for chat messages

# Load environment variables
notebook_path = Path().absolute()
parent_dir = notebook_path.parent
model_deployment = 'gpt-4.1'
load_dotenv(parent_dir / '../.env', override=True)

# Retrieve from environment
connection_string = os.environ.get("PROJECT_CONNECTION_STRING")
model_deployment = 'gpt-4o'

try:
    # Create the project client
    project_client = AIProjectClient.from_connection_string(
        credential=DefaultAzureCredential(),
        conn_str=connection_string,
    )
    print("✅ Successfully created AIProjectClient")
except Exception as e:
    print("❌ Error initializing client:", e)
# Out:
# ✅ Successfully created AIProjectClient

# %% [markdown]
# ### 1. Role Prompting
#
# El role prompting es una técnica poderosa en prompt engineering que permite guiar a los modelos de IA para adoptar personalidades o especializaciones específicas. Este enfoque puede mejorar significativamente la calidad y relevancia de las respuestas generadas por la IA, haciendo que sean más adecuadas para tareas o dominios específicos.

# %%
# We'll define a function that runs chat completions with a system prompt & user prompt
roles = [
    ("Asesor Financiero", "Eres un asesor financiero experimentado en un banco. Explica los beneficios y los riesgos potenciales asociados con:"),
    ("Oficial de Préstamos", "Eres un oficial de préstamos con experiencia en un banco. Explica los pasos clave y los requisitos necesarios para:"),
    ("Representante de Servicio al Cliente", "Eres un representante de servicio al cliente amable en un banco. Proporciona una explicación clara y accesible de:")
]

topic = "El crédito hipotecario"

def chat_with_assistant(system_text: str):
    """Use chat completions to get a response from our LLM, with system instructions."""
    # Our system message template
    # We'll open the chat completions client
    with project_client.inference.get_chat_completions_client() as chat_client:
        # Construct messages: system + user
        system_message = SystemMessage(content=system_text)
        user_message = UserMessage(content=topic)

        # Send the request
        response = chat_client.complete(
            model=model_deployment,
            messages=[system_message, user_message]
        )

        return response.choices[0].message.content

# %%
for role, system_text in roles:
    print(f"\n--- Explicacion {role} ---\n")
    response = chat_with_assistant(system_text)
    print(response)
    print("-" * 50)
# Out:
# --- Explicacion Asesor Financiero ---
#
# El crédito hipotecario es una herramienta financiera que permite a las personas adquirir una propiedad sin necesidad de disponer de la totalidad del dinero en un solo momento. Sin embargo, al igual que cualquier producto financiero, tiene sus beneficios y riesgos. A continuación, detallo ambos aspectos para que puedas tomar una decisión informada:
#
# ### Beneficios del Crédito Hipotecario
#
# 1. **Acceso a Propiedad**:
#    - Permite a las personas acceder a la propiedad de una vivienda, algo que sería difícil de lograr únicamente con ahorros personales.
#
# 2. **Tasa de Interés Competitiva**:
#    - Los créditos hipotecarios suelen tener tasas de interés más bajas en comparación con otros tipos de préstamos, como los préstamos personales o las tarjetas de crédito.
#
# 3. **Plazos Largos**:
#    - Ofrecen plazos de pago extendidos, que pueden ir desde 15 hasta 30 años, permitiendo pagos mensuales más manejables.
#
# 4. **Beneficios Fiscales**:
#    - En algunos países, los intereses hipotecarios pueden ser deducibles de impuestos, proporcionando un beneficio fiscal que puede reducir la carga tributaria.
#
# 5. **Apreciación del Valor de la Propiedad**:
#    - Con el tiempo, la propiedad adquirida puede aumentar su valor, lo que puede resultar en una ganancia de capital considerable si decides venderla en el futuro.
#
# 6. **Formación de Activo Patrimonial**:
#    - Al pagar tu hipoteca, estás construyendo capital y transformando ese pago mensual en algo tangible, a diferencia de pagar alquiler.
#
# ### Riesgos Potenciales del Crédito Hipotecario
#
# 1. **Riesgo de No Pago**:
#    - Si no puedes hacer los pagos mensuales, corres el riesgo de incumplimiento de pago, lo que podría llevar a la pérdida de la propiedad a través de la ejecución hipotecaria.
#
# 2. **Fluctuaciones en Tasa de Interés**:
#    - Si tienes una hipoteca con una tasa de interés variable, los pagos mensuales pueden aumentar si las tasas de interés suben, afectando tu presupuesto.
#
# 3. **Costos Adicionales**:
#    - Los créditos hipotecarios pueden incluir costos adicionales como seguros, impuestos y comisiones que pueden incrementar el costo total del préstamo.
#
# 4. **Devaluación de la Propiedad**:
#    - Existe el riesgo de que el valor de la propiedad disminuya debido a condiciones de mercado, llevando a una situación de valor negativo en la que debes más dinero del que vale la propiedad.
#
# 5. **Responsabilidad a Largo Plazo**:
#    - Un crédito hipotecario es una responsabilidad financiera a largo plazo que puede limitar tu flexibilidad económica para tomar otros créditos o inversiones.
#
# 6. **Implicaciones en el Crédito**:
#    - No cumplir con los pagos puede afectar gravemente tu calificación crediticia, complicando la obtención de futuros créditos o mejores tasas de interés.
#
# ### Conclusión
# Un crédito hipotecario puede ser una herramienta poderosa para adquirir una propiedad y construir patrimonio a lo largo del tiempo. Sin embargo, es fundamental evaluar tu situación financiera personal, considerar los riesgos y asegurarte de que puedas cumplir con los pagos mensuales a largo plazo. Evaluar los pros y los contras, y posiblemente buscar la asesoría de un experto financiero, te permitirá tomar una decisión informada y adecuada para tus necesidades.
# --------------------------------------------------
#
# --- Explicacion Oficial de Préstamos ---
#
# Un crédito hipotecario es un préstamo destinado a la compra de bienes inmuebles, donde el inmueble actúa como garantía del préstamo. Aquí tienes los pasos clave y los requisitos necesarios para solicitar un crédito hipotecario:
#
# ### Pasos clave para obtener un crédito hipotecario:
#
# 1. **Evaluación preliminar**: Contacta a tu banco o institución financiera para obtener información sobre los créditos hipotecarios que ofrecen. Realiza una evaluación preliminar de tu capacidad de pago y de los diferentes tipos de créditos hipotecarios disponibles (tasa fija, tasa variable, combinada, etc.).
#
# 2. **Análisis financiero**: Realiza un presupuesto personal y evalúa tu capacidad de pago tomando en cuenta tus ingresos, egresos y deudas actuales. Utiliza simuladores de crédito hipotecario para tener una idea de las mensualidades y plazos que puedes afrontar.
#
# 3. **Reunir la documentación**: Prepara la documentación necesaria para la solicitud del crédito. Esto suele incluir pruebas de identidad, comprobantes de ingresos, historial crediticio, y cualquier otra documentación requerida por la institución financiera.
#
# 4. **Solicitud del crédito**: Llena la solicitud del crédito hipotecario en el banco o institución financiera elegida. Presenta toda la documentación requerida y espera la evaluación preliminar.
#
# 5. **Evaluación del crédito**: La institución financiera realizará un análisis exhaustivo de tu situación financiera y crediticia. Esto incluye la verificación de tus ingresos, historial crediticio y capacidad para hacer frente al compromiso financiero.
#
# 6. **Aprobación y oferta**: Si cumples con los requisitos y pasas la evaluación crediticia, la institución financiera aprobará tu crédito y te presentará una oferta formal, incluyendo montos, tasas de interés, plazos y condiciones del préstamo.
#
# 7. **Valoración del inmueble**: El banco realizará una tasación del inmueble que servirá como garantía del préstamo. Esta valoración determinará el monto máximo que el banco está dispuesto a prestar.
#
# 8. **Condiciones y firma del contrato**: Revisa cuidadosamente las condiciones de la oferta. Si estás de acuerdo, procedes a la firma del contrato de crédito hipotecario.
#
# 9. **Trámites legales**: Se realiza la escrituración y registro del inmueble a tu nombre, así como la inscripción de la hipoteca en el registro de la propiedad. Esto generalmente se lleva a cabo ante notario público.
#
# 10. **Desembolso del crédito**: Una vez completados todos los trámites legales, la institución financiera procederá al desembolso del crédito, el cual generalmente se entrega al vendedor del inmueble.
#
# ### Requisitos necesarios para solicitar un crédito hipotecario:
#
# 1. **Identificación**: Documento de identidad oficial válido (DNI, pasaporte, etc.).
#
# 2. **Comprobante de ingresos**: Recibos de nómina, estado de cuenta bancario, o declaración de impuestos, dependiendo del tipo de empleo (asalariado, autónomo, empresario).
#
# 3. **Historial crediticio**: Reporte de crédito, que muestre tu historial de pagos y deudas pendientes. Es importante tener un buen puntaje crediticio.
#
# 4. **Comprobante de domicilio**: Facturas de servicios (agua, luz, teléfono) para verificar tu dirección actual.
#
# 5. **Estado civil**: En algunos casos, acta de matrimonio, pruebas de divorcio o defunción, si aplica.
#
# 6. **Antigüedad laboral**: Generalmente se requiere un mínimo de antigüedad en tu empleo actual, que puede variar de 6 meses a 2 años, dependiendo de la institución.
#
# 7. **Ahorros o enganche**: Porcentaje del valor del inmueble que deberás pagar de tu bolsillo, generalmente entre el 10% y 20%.
#
# 8. **Documentación del inmueble**: Información referente al inmueble que deseas comprar, como el título de propiedad, certificado de libertad de gravamen, avalúo, entre otros.
#
# ### Consejos adicionales:
#
# - **Comparativa de ofertas**: Compara las diferentes ofertas de crédito hipotecario disponibles en diferentes instituciones para encontrar las mejores condiciones que se adapten a tus necesidades.
# - **Consulta asesores**: Si tienes dudas, no dudes en consultar a un asesor financiero o hipotecario para guiarte en el proceso.
# - **Revisión legal**: Asegúrate de que toda la documentación del inmueble esté en regla y libre de problemas legales antes de proceder con la compra.
#
# Estos pasos y requisitos te proporcionarán una guía para obtener un crédito hipotecario y tomar decisiones informadas sobre la compra de tu propiedad.
# --------------------------------------------------
#
# --- Explicacion Representante de Servicio al Cliente ---
#
# ¡Claro! Estoy encantado de explicarte sobre el crédito hipotecario.
#
# Un crédito hipotecario es un préstamo a largo plazo que te ofrece un banco o institución financiera para comprar una vivienda. Aquí están los puntos clave:
#
# 1. **Garantía**: El préstamo está respaldado por la propiedad que compras. Esto significa que si no puedes pagar el préstamo, el banco tiene el derecho de quedarse con la propiedad.
#
# 2. **Plazos**: Generalmente, los plazos para pagar un crédito hipotecario varían entre 10 y 30 años. Esto permite que los pagos mensuales sean más bajos, pero implica que pagarás intereses durante un período prolongado.
#
# 3. **Intereses**: Al igual que otros préstamos, hay una tasa de interés que se aplica. Esta puede ser fija (la misma durante todo el préstamo) o variable (puede cambiar en función del mercado).
#
# 4. **Enganche**: Normalmente, se requiere que des un pago inicial o enganche, que es un porcentaje del valor de la propiedad. Esto puede variar, pero comúnmente es entre el 10% y el 20%.
#
# 5. **Requisitos**: Para calificar para un crédito hipotecario, necesitas demostrar buenos antecedentes financieros, un ingreso estable, y generalmente un buen historial crediticio.
#
# 6. **Tipos de Hipotecas**:
#    - *Hipoteca Tradicional*: Un préstamo a tasa fija o variable que se usa generalmente para comprar una casa.
#    - *Hipoteca con interés solamente*: Durante un período, solo pagas los intereses, luego comienzas a pagar el principal y los intereses.
#    - *Hipoteca de Tasa Ajustable*: La tasa de interés cambia periódicamente, lo que puede influir en la cantidad de los pagos mensuales.
#
# 7. **Beneficios**: Comprar una casa es una gran inversión, y un crédito hipotecario puede hacer que esta inversión sea más accesible. Además, en muchos lugares, los intereses de tu crédito hipotecario pueden ser deducibles de impuestos.
#
# En resumen, un crédito hipotecario es una herramienta financiera que te permite adquirir una propiedad y pagarla en cuotas a lo largo de varios años. Siempre es importante revisar y comparar las opciones que ofrecen diferentes instituciones para encontrar la que mejor se adapte a tus necesidades.
#
# ¡Espero que esta información te haya sido útil! Si tienes alguna pregunta adicional, no dudes en preguntar.
# --------------------------------------------------

# %% [markdown]
# ### 2. Output Formatting
#
# Una longitud y un formato de salida consistentes son cruciales para la experiencia del usuario y la claridad de la interfaz. Las restricciones ayudan a mantener esta consistencia, evitando una variabilidad abrumadora en el texto generado.

# %%
structured_output_prompt = PromptTemplate.from_string(prompt_template="""
    system:
    Eres un experto en banca. 
    Extrae la evaluación crediticia del cliente, los productos financieros recomendados y el plan de acción a futuro a 
    partir del siguiente texto. 
    Devuelve la información en una tabla markdown
                                                                                             
    user:
    Texto: {{input_text}}                                        
    """
)

text = """
El cliente, Juan Pérez, de 40 años, ha mantenido en los últimos 5 años un comportamiento financiero ejemplar. Su historial crediticio es intachable, sin registros de morosidad y con pagos puntuales en todas sus cuentas. 
Se recomienda evaluar productos financieros como líneas de crédito, tarjetas de crédito con beneficios exclusivos y opciones de inversión en fondos de bajo riesgo. 
Como plan de acción, se sugiere implementar un programa de asesoría financiera personalizada que incluya revisiones trimestrales del portafolio y estrategias para optimizar su capacidad de endeudamiento.
"""

with project_client.inference.get_chat_completions_client() as chat_client:
        # Create the chain using the prompt and model
        messages = structured_output_prompt.create_messages(
            input_text=text
        )
        response = chat_client.complete(
            messages=messages,
            model=model_deployment,
        )

        print("\n--- Estructura de salida ---\n")
        print("Texto de entrada:", text)
        print("Texto de salida:", response.choices[0].message.content)
        # json_str = response.choices[0].message.content
        # json_str = json_str.replace("```json", "").replace("```", "").strip()
        # try:
        #     import json
        #     json_obj = json.loads(json_str)
        #     print("JSON:", json_obj)
        # except json.JSONDecodeError as e:   
        #     print("Error decoding JSON:", e)
            # print("Raw response:", json_str)
# Out:
# --- Estructura de salida ---
#
# Texto de entrada:
# El cliente, Juan Pérez, de 40 años, ha mantenido en los últimos 5 años un comportamiento financiero ejemplar. Su historial crediticio es intachable, sin registros de morosidad y con pagos puntuales en todas sus cuentas.
# Se recomienda evaluar productos financieros como líneas de crédito, tarjetas de crédito con beneficios exclusivos y opciones de inversión en fondos de bajo riesgo.
# Como plan de acción, se sugiere implementar un programa de asesoría financiera personalizada que incluya revisiones trimestrales del portafolio y estrategias para optimizar su capacidad de endeudamiento.
#
# Texto de salida: | Información                                    | Detalle                                                                                           |
# |------------------------------------------------|---------------------------------------------------------------------------------------------------|
# | Evaluación de crediticia del cliente           | Historial crediticio intachable, sin registros de morosidad y pagos puntuales en todas sus cuentas |
# | Productos financieros recomendados             | Líneas de crédito, tarjetas de crédito con beneficios exclusivos, opciones de inversión en fondos de bajo riesgo |
# | Plan de acción a futuro                        | Implementar un programa de asesoría financiera personalizada con revisiones trimestrales del portafolio y estrategias para optimizar su capacidad de endeudamiento |

# %% [markdown]
# ### 3. Chain-of-Thought (CoT) Prompting
#
# A medida que los modelos de lenguaje de IA se vuelven más avanzados, existe una necesidad creciente de guiarlos hacia la producción de salidas más transparentes, lógicas y verificables. La técnica de CoT prompting aborda esta necesidad al incentivar a los modelos a mostrar su proceso de trabajo, de manera similar a cómo los humanos abordan tareas complejas de resolución de problemas. Esta técnica no solo mejora la precisión de las respuestas de la IA, sino que también las hace más interpretables y confiables.

# %%
standard_prompt = PromptTemplate.from_string(prompt_template="""
    system:
    Responde a la pregunta de manera clara y concisa.
                                             
    user:
    Pregunta: {{question}}                                        
    """
)

advanced_cot_prompt = PromptTemplate.from_string(prompt_template="""
    system:                                        
    Resuelve el siguiente problema paso a paso. Para cada paso:
    1. Indica lo que vas a calcular
    2. Escribe la fórmula que utilizarás (si aplica)
    3. Realiza el cálculo
    4. Explica el resultado
                                             
    user:
    Pregunta: {{question}}
"""
)

challenging_question = """
Un cliente de un banco deposita $10,000 en una cuenta con una tasa de interés anual del 5% compuesta mensualmente.
Adicionalmente, aporta $200 al final de cada mes.
Determine cuánto tiempo tomará que el saldo de la cuenta alcance los $20,000.
Exprese su respuesta en años y meses, redondeando al mes más cercano.
"""

def create_response(prompt_template: PromptTemplate, question: str):
    """Create a chain of thought using the provided prompt and model."""
    with project_client.inference.get_chat_completions_client() as chat_client:
        # Create the chain using the prompt and model
        messages = prompt_template.create_messages(
            question=question
        )
        response = chat_client.complete(
            messages=messages,
            model=model_deployment,
        )

        return response.choices[0].message.content


standard_response = create_response(standard_prompt, challenging_question)
cot_response =  create_response(advanced_cot_prompt, challenging_question)

print("Respuesta Estándar:")
print(standard_response)
print("\nRespuesta de COT:")
print(cot_response)
# Out:
# Respuesta Estándar:
# Para resolver este problema, usaremos la fórmula del valor futuro de una serie de pagos con interés compuesto mensual. La fórmula para calcular el saldo futuro \( A \) de una cuenta con depósitos regulares es:
#
# \[ A = P \left(1 + \frac{r}{n}\right)^{nt} + \frac{PMT \left(\left(1 + \frac{r}{n}\right)^{nt} - 1\right)}{\frac{r}{n}} \]
#
# donde:
# - \( P \) es el depósito inicial ($10,000).
# - \( PMT \) es el depósito mensual recurrente ($200).
# - \( r \) es la tasa de interés anual (0.05).
# - \( n \) es el número de períodos de capitalización por año (12).
# - \( t \) es el número de años.
# - \( A \) es el saldo futuro deseado ($20,000).
#
# Reorganizando para resolver \( t \) con los valores dados:
#
# \[ 20,000 = 10,000 \left(1 + \frac{0.05}{12}\right)^{12t} + \frac{200 \left(\left(1 + \frac{0.05}{12}\right)^{12t} - 1\right)}{\frac{0.05}{12}} \]
#
# Para hallar el tiempo \( t \), es más práctico usar un enfoque iterativo o una calculadora financiera o una hoja de cálculo debido a la naturaleza compleja de la ecuación.
#
# Usando un cálculo iterativo o una calculadora financiera, encontraremos que:
#
# Después de aproximadamente 3 años y 6 meses, el saldo de la cuenta alcanzará $20,000.
#
# Respuesta de COT:
# Para resolver este problema, vamos a utilizar la fórmula del valor futuro de una anualidad ordinaria con interés compuesto. La combinación de un depósito inicial con aportaciones periódicas y el interés compuesto mensualmente es un problema que requiere fórmulas financieras.
#
# Vamos a dividir el problema en dos partes:
# 1. La parte del depósito inicial que se capitaliza con interés compuesto.
# 2. La suma de las aportaciones mensuales que se montan gradualmente y también se capitalizan.
#
# ## Parte 1: Depósito inicial con interés compuesto
#
# ### Paso 1: Calcular el valor futuro del depósito inicial.
#
# **Fórmula**: \( A = P \left(1 + \frac{r}{n}\right)^{nt} \)
#
# Donde:
# - \( A \) es el monto futuro
# - \( P \) es el monto principal inicial ($10,000)
# - \( r \) es la tasa de interés anual (0.05)
# - \( n \) es el número de veces que se capitaliza el interés por año (12)
# - \( t \) es el tiempo en años que estamos buscando
#
# ### Paso 2: Determinar el valor futuro de las aportaciones periódicas.
#
# **Fórmula**: \( FV = PMT \cdot \frac{\left(1 + \frac{r}{n}\right)^{nt} - 1}{\left(\frac{r}{n}\right)} \)
#
# Donde:
# - \( FV \) es el valor futuro de la serie de pagos
# - \( PMT \) es el pago periódico ($200)
# - \( r \) es la tasa de interés anual (0.05)
# - \( n \) es el número de veces que se capitaliza el interés por año (12)
# - \( t \) es el tiempo en años que estamos buscando
#
# ## Parte 3: Condicionar la suma de ambas fórmulas para alcanzar $20,000
#
# Queremos que la suma de ambas partes sea igual a $20,000:
#
# \( FV (\text{total}) = 10,000 \left(1 + \frac{0.05}{12}\right)^{12t} + 200 \left(\frac{\left(1 + \frac{0.05}{12}\right)^{12t} - 1}{\left(\frac{0.05}{12}\right)}\right) \)
#
# Vamos a usar prueba y error en una hoja de cálculo o calculadora para encontrar el \( t \) aproximado.
#
# ### Cálculos aproximados usando prueba y error:
#
# Para encontrar el valor exacto de \( t \), hacemos cálculos incrementales:
#
# **Intento: \( t = 4 \) años (4 * 12 meses = 48 meses)**
#
# - Depósito inicial crece a:
#   \( 10,000 \left(1 + \frac{0.05}{12}\right)^{48} \approx 10,000 \left(1 + 0.0041667\right)^{48} \approx 10,000 \left(1.22139\right) \approx 12,213.9 \)
#
# - Aportaciones mensuales crecen a:
#   \( 200 \left(\frac{(1 + \frac{0.05}{12})^{48} - 1}{0.0041667}\right) \approx 200 \left(\frac{(1.22139 - 1)}{0.0041667}\right) \approx 200 \left(53.155\right) \approx 10,631 \)
#
# - Suma total en 4 años: \( 12,213.9 + 10,631 \approx 22,844.9 \)
#
# Como el monto es superior a $20,000, reducimos el tiempo.
#
# **Intento: \( t = 3.4 \) años (3.4 * 12 meses = 40.8 meses)**
#
# - Depósito inicial crece a:
#   \( 10,000 \left(1 + \frac{0.05}{12}\right)^{40.8} \approx 10,000 \left(1.1785\right) \approx 11,785 \)
#
# - Aportaciones mensuales crecen a:
#   \( 200 \left(\frac{(1 + \frac{0.05}{12})^{40.8} - 1}{0.0041667}\right) \approx 200 \left(\frac{(1.1785 - 1)}{0.0041667}\right) \approx 200 \left(43.49\right) \approx 8,698 \)
#
# - Suma total en 3.4 años: \( 11,785 + 8,698 \approx 20,483 \)
#
# Esto nos da un monto todavía superior a $20,000. Ajustando aún más:
#
# Aproximando el valor entre anualidades \( t \approx 3.3 \times 12 \approx 40 \) meses.
#
# ## Conclusión:
# El tiempo necesario para que el saldo de la cuenta alcance $20,000 es aproximado a **3 años y 4 meses**.

# %% [markdown]
# ### 4. Few-Shot Prompting
#
# El aprendizaje automático tradicional a menudo requiere conjuntos de datos grandes para el entrenamiento, lo que puede ser un proceso que consume mucho tiempo y recursos. El Few-Shot Learning y el In-Context Learning abordan esta limitación aprovechando el poder de los grandes modelos de lenguaje para realizar tareas con solo unos pocos ejemplos. Este enfoque es particularmente valioso en escenarios donde los datos etiquetados son escasos o costosos de obtener.

# %%
few_shot_prompt_template = PromptTemplate.from_string(prompt_template="""
        Clasifica el sentimiento como Positivo, Negativo o Neutral.

        Ejemplos:
        Texto: La atención en este banco es excepcional.
        Sentimiento: Positivo

        Texto: Las comisiones de este banco son abusivas.
        Sentimiento: Negativo

        Texto: El servicio del cajero automático es regular.
        Sentimiento: Neutral

        Ahora, clasifica lo siguiente:
        Texto:{{input_text}}
"""
)

examples = [
        (
                "El servicio en la sucursal fue tan excepcional que me sentí como en un resort exclusivo, donde cada detalle fue cuidado y la atención personalizada hizo la diferencia.",
                "Positivo"
        ),
        (
                "La espera en el banco fue interminable y la información proporcionada resultó tan confusa que terminé sintiendo frustración y desilusión, lo cual empañó toda la experiencia.",
                "Negativo"
        ),
        (
                "El banco presentó una experiencia balanceada: se notaron esfuerzos innovadores, pero algunos aspectos del servicio dejaron pasar oportunidades de mejora, generando una sensación de regularidad.",
                "Neutral"
        ),
        (
                "La atención del personal fue creativa y proactiva, ofreciendo soluciones personalizadas y sugerencias innovadoras que realmente superaron mis expectativas.",
                "Positivo"
        ),
        (
                "Aunque la interacción fue amable, la falta de seguimiento detallado en mis consultas provocó cierta incertidumbre y una sensación de que el servicio podría ser más completo en futuras ocasiones.",
                "Neutral"
        )
]


with project_client.inference.get_chat_completions_client() as chat_client:
        for example in examples:
                # Create the chain using the prompt and model
                messages = few_shot_prompt_template.create_messages(
                        input_text=example[0]
                )
                response = chat_client.complete(
                        messages=messages,
                        model=model_deployment,
                )

                print(f"Texto: {example[0]}")
                print(f"Sentimiento: {response.choices[0].message.content}")
                print("-" * 50)
# Out:
# Texto: El servicio en la sucursal fue tan excepcional que me sentí como en un resort exclusivo, donde cada detalle fue cuidado y la atención personalizada hizo la diferencia.
# Sentimiento: Sentimiento: Positivo
# --------------------------------------------------
# Texto: La espera en el banco fue interminable y la información proporcionada resultó tan confusa que terminé sintiendo frustración y desilusión, lo cual empañó toda la experiencia.
# Sentimiento: Sentimiento: Negativo
# --------------------------------------------------
# Texto: El banco presentó una experiencia balanceada: se notaron esfuerzos innovadores, pero algunos aspectos del servicio dejaron pasar oportunidades de mejora, generando una sensación de regularidad.
# Sentimiento: Sentimiento: Neutral
# --------------------------------------------------
# Texto: La atención del personal fue creativa y proactiva, ofreciendo soluciones personalizadas y sugerencias innovadoras que realmente superaron mis expectativas.
# Sentimiento: Sentimiento: Positivo
# --------------------------------------------------
# Texto: Aunque la interacción fue amable, la falta de seguimiento detallado en mis consultas provocó cierta incertidumbre y una sensación de que el servicio podría ser más completo en futuras ocasiones.
# Sentimiento: Sentimiento: Neutral
# --------------------------------------------------

# %% [markdown]
# ### 5. Tree-of-Thought (ToT) Prompting
#
# Los modelos de lenguaje de gran escala a veces pueden producir resultados inconsistentes o poco fiables. Al aprovechar múltiples caminos de razonamiento y agregando los resultados, podemos mejorar la solidez y precisión de las respuestas generadas por la IA. Este enfoque es particularmente útil para tareas complejas de resolución de problemas, donde un único camino de razonamiento podría ser insuficiente o propenso a errores.

# %%
def generate_multiple_paths(problem, num_paths=3):
    prompt_template = PromptTemplate.from_string(
        prompt_template="""
        Resuelve el siguiente problema utilizando un enfoque único. Esta es la ruta de razonamiento {{path_number}}.
        Problema: {{problem}}
        Ruta de razonamiento {{path_number}}:
    """
    )

    paths = []
    with project_client.inference.get_chat_completions_client() as chat_client:
        for i in range(num_paths):
            messages = prompt_template.create_messages(
                problem=problem,
                path_number=i + 1
            )
            response = chat_client.complete(
                messages=messages,
                model=model_deployment,
            )
            paths.append(response.choices[0].message.content)
    
    return paths

# %%
problem = "Un cliente deposita $20,000 en una cuenta de ahorros que ofrece un 5% de interés anual compuesto. ¿Cuánto dinero tendrá en la cuenta después de 10 años?"
paths = generate_multiple_paths(problem)

# %%
def aggregate_results(paths:list[str]) -> str:

    prompt_template = PromptTemplate.from_string(
        """
        Analiza las siguientes rutas de razonamiento y determina la respuesta más coherente. Si existen discrepancias, explica por qué y proporciona la respuesta más probable.
        Rutas de razonamiento:
        {{paths}}
        
        Respuesta más coherente:
        """
    )
    with project_client.inference.get_chat_completions_client() as chat_client:
        messages = prompt_template.create_messages(
                paths="\n".join(paths),
            )
        response = chat_client.complete(
            messages=messages,
            model=model_deployment,
        )
        
    return response.choices[0].message.content

# %%
aggregated_result = aggregate_results(paths)
print("Resultado agregado:\n", aggregated_result)
# Out:
# Resultado agregado:
#  Las tres rutas de razonamiento presentadas son consistentes y usan la fórmula correcta para calcular el interés compuesto:
#
# \[ A = P \left( 1 + \frac{r}{n} \right)^{nt} \]
#
# Las rutas de razonamiento desglosan la fórmula con los mismos valores inicules:
# - \( P = 20000 \)
# - \( r = 0.05 \)
# - \( n = 1 \)
# - \( t = 10 \)
#
# Cada ruta luego simplifica la fórmula paso a paso resultando en el cálculo final:
#
# 1. Calcular dentro del paréntesis: \( 1 + 0.05 = 1.05 \)
# 2. Elevar esta cantidad a la potencia de \(10\): \( (1.05)^{10} \approx 1.62889 \)
# 3. Multiplicar por el principal \( 20000 \times 1.62889 = 32577.80 \)
#
# La única variación entre las soluciones presentadas está en la aproximación final. Una presenta:
#
# \[ A \approx 32577.80 \]
# mientras que otra muestra:
#
# \[ A \approx 32577.84 \]
#
# Dado que \( 1.05^{10} \) calculado con precisión es aproximadamente 1.628894626777442, cuando se multiplica por 20000, obtendrás un número más cercano a 32577.89253554884.
#
# Redondeando correctamente a dos decimales nos da aproximadamente $32,577.89.
#
# Lo mas preciso debería ser alrededor de $32,577.89. Sin embargo todos los valores aproximados a $32,577.80 están razonablemente cerca del correcto.
#
# Por tanto, la respuesta más coherente y cercana es:
#
# **$32,577.89**

# %% [markdown]
# ### 6. Rephrase and Responde (RaR) Prompting
#
# RaR permite a los LLMs parafrasear y ampliar las preguntas en un solo prompt, demostrando una comprensión mejorada y una mayor precisión en las respuestas.

# %%
prompt_template = PromptTemplate.from_string(
        """
        {{question}}

        Given the above question, rephrase and expand it to help you do better answering. Maintain all information in the original question.
        Just rephrase the question, do not answer it.
        """
    )

question = "Una persona depositó 20K en 2015 en una cuenta con interés compuesto a una tasa cercana al 5%. ¿Qué cantidad se podría obtener en 2025 ?"

with project_client.inference.get_chat_completions_client() as chat_client:
    messages = prompt_template.create_messages(
            question = question,
        )
    response = chat_client.complete(
        messages=messages,
        model=model_deployment,
    )
        
    print("Pregunta original:\n", question)
    print("Pregunta reescrita:\n", response.choices[0].message.content)
# Out:
# Pregunta original:
#  Una persona depositó 20K en 2015 en una cuenta con interés compuesto a una tasa cercana al 5%. ¿Qué cantidad se podría obtener en 2025 ?
# Pregunta reescrita:
#  Una persona realizó un depósito de $20,000 en el año 2015 en una cuenta bancaria que ofrece un interés compuesto a una tasa cercana al 5% anual. ¿Cuál sería el monto acumulado en la cuenta al cabo de 10 años, es decir, en el año 2025?
